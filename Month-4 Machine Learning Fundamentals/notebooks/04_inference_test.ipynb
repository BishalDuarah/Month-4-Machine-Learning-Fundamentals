# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

from src.model_inference import predict_churn

sample_input = {
    "Gender": "Female",
    "Senior Citizen": 0,
    "Partner": "Yes",
    "Dependents": "No",
    "Tenure Months": 5,
    "Phone Service": "Yes",
    "Multiple Lines": "No",
    "Internet Service": "Fiber optic",
    "Online Security": "No",
    "Online Backup": "No",
    "Device Protection": "No",
    "Tech Support": "No",
    "Streaming TV": "Yes",
    "Streaming Movies": "Yes",
    "Contract": "Month-to-month",
    "Paperless Billing": "Yes",
    "Payment Method": "Electronic check",
    "Monthly Charges": 85.0,
    "Total Charges": 425.0,
    "CLTV": 3000
}

result = predict_churn(sample_input, threshold=0.5)
print(result)
# Out:
# {'churn_probability': 0.8969812413632474, 'churn_prediction': 1}
